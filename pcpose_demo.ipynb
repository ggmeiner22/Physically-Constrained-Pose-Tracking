# %% [markdown]
# <a href="https://colab.research.google.com/github/ggmeiner22/Physically-Constrained-Pose-Tracking/blob/main/pcpose_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone Repo

# %%
# !rm -rf /content/sample_data

# 1) Clone your repo (replace with your URL)
# !git clone https://github.com/ggmeiner22/Physically-Constrained-Pose-Tracking

# 2) Change into the repo directory
# %cd /content/Physically-Constrained-Pose-Tracking

# 3) Optional: list files to verify
# !ls
# Out:
# fatal: destination path 'Physically-Constrained-Pose-Tracking' already exists and is not an empty directory.
# /content/Physically-Constrained-Pose-Tracking
# create_manifest.py  LICENSE	 pcpose		    README.md	      tools
# data		    Makefile	 pcpose_demo.ipynb  requirements.txt  train.py
# datasets	    MANIFEST.in  pyproject.toml     setup.cfg

# %% [markdown]
# # Install dependencies

# %%
# !pip install --upgrade pip setuptools wheel

# Install requirements
# !pip install -r requirements.txt

# Optional: install the repo as a package (like `make dev`)
# !pip install -e .
# Out:
# ...
# Obtaining file:///content/Physically-Constrained-Pose-Tracking
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for pcpose (pyproject.toml) ... done
#   Created wheel for pcpose: filename=pcpose-0.1.0-0.editable-py3-none-any.whl size=4986 sha256=2614b9071214f496a96f2f1d622d71c6a9d44ebe73eb9195d3a638e2769f1896
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hqowoule/wheels/06/c3/b2/961d6568358cdeee0ef2ee4a599f12474671bc9252d5f55269
# Successfully built pcpose
# ...

# %% [markdown]
# # Manifest generation

# %%
# !python tools/gen_manifest.py --root datasets --outdir data
# Out:
# Wrote data/manifest_train.csv with 24 items
# Wrote data/manifest_val.csv with 4 items
# Wrote data/manifest_test.csv with 2 items

# %% [markdown]
# # Training

# %%
# !python train.py \
  --model temporal \
  --train_manifest data/manifest_train.csv \
  --val_manifest data/manifest_val.csv \
  --test_manifest data/manifest_test.csv \
  --epochs 10 \
  --batch_size 4 \
  --clip_len 32
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 223MB/s]
# Traceback (most recent call last):
#   File "/content/Physically-Constrained-Pose-Tracking/train.py", line 280, in <module>
#     main()
#   File "/content/Physically-Constrained-Pose-Tracking/train.py", line 242, in main
#     tr_logs = train_epoch_seq_batches(model, train_loader, opt)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Physically-Constrained-Pose-Tracking/train.py", line 113, in train_epoch_seq_batches
#     for batch in tqdm(loader, desc="Train", leave=False):
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
# ...

# %% [markdown]
# # Visualization

# %%
SCEN = "sliding"
VIDEO = "datasets/marble/marble-on-track-sim-1.mp4"

# !python tools/visualize_ekf_vs_raw.py --scenario {SCEN} --video_path {VIDEO}
